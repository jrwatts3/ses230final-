# %% [markdown]
# #### WELCOME TO CLEVELAND: THE GAME

# %% [markdown]
# **********************************

# %%
def dn():
    import random
#MAIN MENU
    d = 0
    while d == 0:
        sta = input(str("LOAD GAME? YES OR NO: "))
        sta = sta.lower()
        if sta == "yes":
            print("\nWELCOME TO CLEVELAND\n       THE GAME")
            print("***********************")
    
            beg = input(str("ENTER X TO EMBARK ON YOUR JOURNEY: "))
            beg = beg.lower()
            #characters
            
            if beg == "x":
                print("\nSo, let's begin:\nWho do you want to be?")
                char = input(str("\nPress X to see character descriptions and choose: "))
                char = char.lower()
                if char == "x":
                    game = 0
                    print("***********************\nEli (he/him): Eli is a strong-headed, strong-willed boy who had to grow up on his own.\nparents were barely physically there, 100% emotionally absent.\ndoesn’t like to show emotions, not even with those close to him.\nthis character has higher chances of riskier outcome, saying the wrong thing, \nand won’t like most people they encounter. \n\nGreatest strength is his poker face. \nBiggest weakness is not being able to keep his damn mouth shut.\n--\nCeleste (she/her): Celeste is a timid, goody-two shoes. recently moving to the 314 was hard on her.\ndoesn’t ever feel like she fits in. isn’t afraid to talk but doesn’t talk much.\nhas a secret smart mouth. seems like an easy target, but won’t hesitate standing up for herself.\nlikes to follow the rules; this character does NOT like risk and doesn’t perform her best under circumstances\nshe cannot completely control.\n\nGreatest strength is manipulating with sweet talk.\nBiggest weakness is not being able to toughen her demeanor when needed.\n--\nStar (they/them): Star is batshit crazy. ran away from homophobic parents at a young age\nand has been on their own since 15.\nhas done some really sketchy things to survive on their own, but they hold it down.\nhates the rules, hates the police, but what they hate most-- living without thrill.\nthis character an absolute wildcard and basically has a death wish. choose your options wisely.\n\nGreatest strength is their quick thinking in bad situations.\nBiggest weakness is not thinking about how consequences effect those around them.\n--\nYou are more than welcome to choose your own name, but using a named character will influence your ending.")
                    print("***********************")
                    
                    #choose character
                    
                    character = input(str("\nWho will you chose?\n\n"))
    
                    
                    #OPENING SCENE
                    
                    print(character, "is sitting in a car outside of an abandoned highschool. Its 11:00 pm on a random day in June.\nThey aren't sure if they should go in. All possible entrances are boarded up,\nbut Blake knows the way in. Everyone gets out of the car.\nIt is eerily silent, and it is almost as if you can hear everyone's heartbeating out of their chest.\n\nYou get to a boarded up window on the first floor,")
                    print("Do you\n1. Try to look for an easier way in\n2. Climb a dumpster to get to an open window\n3. Use all of your might to rip the damn wood off the window\n")
                    n1 = input()
                    n1 = int(n1)
                    total = 0
                    total = total + n1
                    
                    print("--\nYou have made your way into the school. It looks pretty dangerous here. The ceiling is falling apart and the floor is covered by the waste left by the crumbling walls. You make your way to the stairs, and go up a few floors.\nYou encounter another group of teens and follow them on their way to the roof.\n\nOnce you make it to the fourth floor, people start crawling out of another window.")
                    print("Do you\n1. Try to find a safer way through, maybe another set of stairs?\n2. Follow them, they seem to know what they're doing\n3. Follow Blake, who is trying to climb up by the building's bricks")
                    n2 = input()
                    n2 = int(n2)
                    total = total + n2
                    
                    print("--\nOnce you make it to the roof, you fall in love with the view. You quite literally have never seen something \nas amazing as this. The moon looks huge, as if it was close enough to touch. Out of curiosity,\nyou start walking towards the edge of the roof, and peer down.\nChills run down your spine as the drop looks nearly 100 feet.\n\nSomeone stands next to you. You peer over and notice how attractive they are. They look at you")
                    print("Do you\n1. Nod awkardly with a meek smile\n2. Wave with your signature smile\n3. Hit 'em with the 'Hey Sexy' and a wink")
                    n3 = input()
                    n3 = int(n3)
                    total = total + n3
                    
                    print("--\nThey laugh and say 'hey'. You almost blush, but you just look back out at the view. You talk about what school you go to. Your 18th birthday is next week, and they ask what you're going to do for it")
                    print("Are you\n1. Doing a 'small thing' (you have no plans yet)\n2. Throwing a party and they're invited!\n3. You say 'Hopefully, you', cheeky bastard.")
                    n4 = input()
                    n4 = int(n4)
                    total = total + n4
                    
                    print("--\n You hear a commotion and look over to see some dudes fighting.\nIt is starting to get loud, and if you're too loud at Cleveland, everyone knows the cops come.\nOne guy is backing up way too close to the edge, so you run over")
                    print("Will you\n1. Get between them and tell them to chill\n2. Say 'Hey, idiots! Shut up!\n3. Grab both by the collars and drag them away while telling them the cops are waiting for them downstairs")
                    n5 = input()
                    n5 = int(n5)
                    total = total + n5
                    
                    print("--\nAfter a few minutes, everything seems chill again. Nobody knows where the guys from earlier are, but it doesn't really matter.\nBut then, sirens rang out, LOUD. They were coming.\n'Shit.' Someone whispers. Everyone goes silent and start to hide. The hottie from earlier grabs your hand in fear")
                    print("Where are you going to hide?\n1. Sit by some old AC systems\n2. Just stay where you are. No way the cops can see this high, right?\n3. Sit on the ledge and swing your feet. What are they gonna do? Come up here?")
                    n6 = input()
                    n6 = int(n6)
                    total = total + n6
                    
                    print("--\nThe cops are getting closer. Don't they have something better to do?\n\nIn the distance, you see at least 4 cars coming. Your heart starts racing. You could get a curfew citation,\nget charged with trespassing, or even get roped up with the kids who definitely have drugs with them.\nYou hear people whispering about how they've heard the city is getting stricter about the building\nYou think about what you could say if you were detained or something")
                    print("You'd say\n1. 'I got pressured into this, please let me go Mr. Officer!'\n2. 'Do you not have any real criminals to be catching right now? A robbery or something?'\n3. 'Oink, oink, piggy'")
                    n7 = input()
                    n7 = int(n7)
                    total = total + n7
                    
                    print("Police cars surround the building. Is it really that serious? The police are using speakerphones to tell everyone to come down.\nYou look around, Blake is waving and jumping at the police like a dumbass.\nYou have no idea where the others are, but you're here with the person who is totally so hot,\nbut you don't even know their name. They then say 'Hey,", character,", I think I'm gonna just go down there.\nI don't want to get in anymore trouble.'\n\nYou almost laugh at them, but then you get a really good look at their face. They look genuinely concerned")
                    print("\nDo you\n1. Consider going with them ... maybe you can get away with a warning?\n2. Nod and let them go\n3. Tell them to give you a kissy!")
                    n8 = input()
                    n8 = int(n8)
                    total = total + n8
                    
                    print("They giggle and give you their socials to talk later. You get butterflies, but good ones. The bad ones come back\nas you see them walk away. Hopefully they don't get in too much trouble. You start to see people\njust get up and follow, just accepting their fate. You look over and see Blake doing the same thing! Super unlike him.\nHe motions you to follow, so you do.\n\nOnce you make it downstairs, you're approached by an officer")
                    print("\nDo you\n1. Start crying\n2. Stay calm\n3. Spit on him")
                    n9 = input()
                    n9 = int(n9)
                    total = total + n9
                    character = character.lower()
                    
                    #ending
                    
                    if (total >= 0 and total <= 10) or (total > 0 and total <= 12 and character == 'eli'):
                        print("YOU FINISHED CLEVELAND:\n\nYour ending: You got away with a warning. You are SUPER lucky.")
                        ending = 1
                        d = 1
                        
                    elif (total > 10 and total <= 20) or (total > 10 and total < 20 and character == 'celeste') or (character == 'star' and total < 17):
                        print("YOU FINISHED CLEVELAND:\n\nYour ending: You got a couple citations. Your mom is pissed\n and you have court in 3 weeks. Good luck.")
                        ending = 2
                        d = 1
                        
                    elif total > 20 or character == 'star':
                        print("YOU FINISHED CLEVELAND:\n\nYour ending: YOU GOT ARRESTED ?!?!!??!!?!? DUDE!!!!!! No way outta this one.\nBad choices mean bad endings, bro.")
                        ending = 3
                        d = 1
                    
            else:
                d = 1
                print("Dude, what do you want? Try again.")
                d = 0
        else:
            d = 1
            print("\nGOODBYE")   
dn()

# %% [markdown]
# COMPUTER SIMULATION

# %%
import random

def simulate_game():
    endings = []
    characters = ['Eli', 'Celeste', 'Star']
    choices = [1, 2, 3]
    character_counts = {'Eli': 0, 'Celeste': 0, 'Star': 0}
    ending_counts = {1: {'Eli': 0, 'Celeste': 0, 'Star': 0},
                     2: {'Eli': 0, 'Celeste': 0, 'Star': 0},
                     3: {'Eli': 0, 'Celeste': 0, 'Star': 0}}
    
    for i in range(150):
        total = 0
        # Choose character
        character = random.choice(characters)
        character_counts[character] += 1
            
        # OPENING SCENE
        print(character, "is sitting in a car outside of an abandoned high school. It's 11:00 pm on a random day in June.\nThey aren't sure if they should go in. All possible entrances are boarded up,\nbut Blake knows the way in. Everyone gets out of the car.\nIt is eerily silent, and it is almost as if you can hear everyone's heartbeating out of their chest.\n\nYou get to a boarded-up window on the first floor,")
        print("Do you\n1. Try to look for an easier way in\n2. Climb a dumpster to get to an open window\n3. Use all of your might to rip the damn wood off the window\n")
        n1 = random.choice(choices)
        total += n1
                    
        print("--\nYou have made your way into the school. It looks pretty dangerous here. The ceiling is falling apart and the floor is covered by the waste left by the crumbling walls. You make your way to the stairs, and go up a few floors.\nYou encounter another group of teens and follow them on their way to the roof.\n\nOnce you make it to the fourth floor, people start crawling out of another window.")
        print("Do you\n1. Try to find a safer way through, maybe another set of stairs?\n2. Follow them, they seem to know what they're doing\n3. Follow Blake, who is trying to climb up by the building's bricks")
        n2 = random.choice(choices)
        total += n2
                    
        print("--\nOnce you make it to the roof, you fall in love with the view. You quite literally have never seen something \nas amazing as this. The moon looks huge, as if it was close enough to touch. Out of curiosity,\nyou start walking towards the edge of the roof, and peer down.\nChills run down your spine as the drop looks nearly 100 feet.\n\nSomeone stands next to you. You peer over and notice how attractive they are. They look at you")
        print("Do you\n1. Nod awkwardly with a meek smile\n2. Wave with your signature smile\n3. Hit 'em with the 'Hey Sexy' and a wink")
        n3 = random.choice(choices)
        total += n3
                    
        print("--\nThey laugh and say 'hey'. You almost blush, but you just look back out at the view. You talk about what school you go to. Your 18th birthday is next week, and they ask what you're going to do for it")
        print("Are you\n1. Doing a 'small thing' (you have no plans yet)\n2. Throwing a party and they're invited!\n3. You say 'Hopefully, you', cheeky bastard.")
        n4 = random.choice(choices)
        total += n4
                    
        print("--\n You hear a commotion and look over to see some dudes fighting.\nIt is starting to get loud, and if you're too loud at Cleveland, everyone knows the cops come.\nOne guy is backing up way too close to the edge, so you run over")
        print("Will you\n1. Get between them and tell them to chill\n2. Say 'Hey, idiots! Shut up!\n3. Grab both by the collars and drag them away while telling them the cops are waiting for them downstairs")
        n5 = random.choice(choices)
        total += n5
                    
        print("--\nAfter a few minutes, everything seems chill again. Nobody knows where the guys from earlier are, but it doesn't really matter.\nBut then, sirens rang out, LOUD. They were coming.\n'Shit.' Someone whispers. Everyone goes silent and starts to hide. The hottie from earlier grabs your hand in fear")
        print("Where are you going to hide?\n1. Sit by some old AC systems\n2. Just stay where you are. No way the cops can see this high, right?\n3. Sit on the ledge and swing your feet. What are they gonna do? Come up here?")
        n6 = random.choice(choices)
        total += n6
                    
        print("--\nThe cops are getting closer. Don't they have something better to do?\n\nIn the distance, you see at least 4 cars coming. Your heart starts racing. You could get a curfew citation,\nget charged with trespassing, or even get roped up with the kids who definitely have drugs with them.\nYou hear people whispering about how they've heard the city is getting stricter about the building\nYou think about what you could say if you were detained or something")
        print("You'd say\n1. 'I got pressured into this, please let me go Mr. Officer!'\n2. 'Do you not have any real criminals to be catching right now? A robbery or something?'\n3. 'Oink, oink, piggy'")
        n7 = random.choice(choices)
        total += n7
                    
        print("Police cars surround the building. Is it really that serious? The police are using speakerphones to tell everyone to come down.\nYou look around, Blake is waving and jumping at the police like a dumbass.\nYou have no idea where the others are, but you're here with the person who is totally so hot,\nbut you don't even know their name. They then say 'Hey,", character,", I think I'm gonna just go down there.\nI don't want to get in any more trouble.'\n\nYou almost laugh at them, but then you get a really good look at their face. They look genuinely concerned")
        print("\nDo you\n1. Consider going with them ... maybe you can get away with a warning?\n2. Nod and let them go\n3. Tell them to give you a kissy!")
        n8 = random.choice(choices)
        total += n8
                    
        print("They giggle and give you their socials to talk later. You get butterflies, but good ones. The bad ones come back\nas you see them walk away. Hopefully, they don't get in too much trouble. You start to see people\njust get up and follow, just accepting their fate. You look over and see Blake doing the same thing! Super unlike him.\nHe motions you to follow, so you do.\n\nOnce you make it downstairs, you're approached by an officer")
        print("\nDo you\n1. Start crying\n2. Stay calm\n3. Spit on him")
        n9 = random.choice(choices)
        total += n9
                    
        #ENDINGGGGGGG
        ending = 0
        if (total >= 0 and total <= 16) or (total > 0 and total <= 12 and character == 'eli'):
            ending = 1
        elif (total > 16 and total <= 20) or (total > 10 and total < 20 and character == 'celeste') or (character == 'star' and total < 17):
            ending = 2
        elif total > 20 or character == 'star':
            ending = 3

        endings.append(ending)
        ending_counts[ending][character] += 1

    print("Character counts:")
    for character, count in character_counts.items():
        print(f"{character}: {count}")

    return endings, ending_counts

endings, ending_counts = simulate_game()

# %%
for ending, counts in ending_counts.items():
    print(f"\nEnding {ending} counts:")
    for character, count in counts.items():
        print(f"  {character}: {count}")

        
print("\n\nEnding 1 count:", endings.count(1))
print("Ending 2 count:", endings.count(2))
print("Ending 3 count:", endings.count(3))
